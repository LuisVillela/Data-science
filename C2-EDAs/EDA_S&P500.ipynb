# %%
import pandas as pd

# %%
df = pd.read_csv('./sp500_companies.csv')

# %%
df.shape
# Out:
# (502, 16)

# %%
df.head()
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 2      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 3      NMS   AMZN       Amazon.com, Inc.       Amazon.com, Inc.
# 4      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology            Consumer Electronics        254.49
# 1              Technology                  Semiconductors        134.70
# 2              Technology       Software - Infrastructure        436.60
# 3       Consumer Cyclical                 Internet Retail        224.92
# 4  Communication Services  Internet Content & Information        191.41
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3846819807232  1.346610e+11          0.061      Cupertino    CA
# ...

# %% [markdown]
# Cuales son los paices

# %%
df_shows = df[df['Industry'] == 'Internet Retails']
df_shows.shape
# Out:
# (0, 16)

# %%
df[df['Industry'] == 'Internet Retail']
# Out:
#     Exchange Symbol         Shortname          Longname             Sector  \
# 3        NMS   AMZN  Amazon.com, Inc.  Amazon.com, Inc.  Consumer Cyclical
# 279      NMS   EBAY         eBay Inc.         eBay Inc.  Consumer Cyclical
#
#             Industry  Currentprice      Marketcap        Ebitda  \
# 3    Internet Retail        224.92  2365033807872  1.115830e+11
# 279  Internet Retail         65.01    31139790848  2.619000e+09
#
#      Revenuegrowth      City State        Country  Fulltimeemployees  \
# 3             0.11   Seattle    WA  United States          1551000.0
# 279           0.03  San Jose    CA  United States            12300.0
#
#                                    Longbusinesssummary   Weight
# 3    Amazon.com, Inc. engages in the retail sale of...  0.04255
# 279  eBay Inc., together with its subsidiaries, ope...  0.00056

# %%
df_shows.dtypes
# Out:
# Exchange                object
# Symbol                  object
# Shortname               object
# Longname                object
# Sector                  object
# Industry                object
# Currentprice           float64
# Marketcap                int64
# Ebitda                 float64
# Revenuegrowth          float64
# City                    object
# State                   object
# Country                 object
# Fulltimeemployees      float64
# Longbusinesssummary     object
# Weight                 float64
# dtype: object

# %%
df_shows_m = df_shows[df['Marketcap'] == 2365033807872]
df_shows_m.shape
# Out:
# /var/folders/yn/vbht61m97rg6wrrbgs95_9k00000gn/T/ipykernel_89593/4191245596.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_shows_m = df_shows[df['Marketcap'] == 2365033807872]
# (0, 16)

# %%
df[df['Currentprice'] > 500]
# Out:
#     Exchange Symbol                        Shortname  \
# 6        NMS   META             Meta Platforms, Inc.
# 11       NYQ    LLY            Eli Lilly and Company
# 14       NYQ     MA          Mastercard Incorporated
# 17       NYQ    UNH  UnitedHealth Group Incorporated
# 18       NMS   COST     Costco Wholesale Corporation
# 21       NMS   NFLX                    Netflix, Inc.
# 33       NYQ    NOW                 ServiceNow, Inc.
# 41       NYQ    TMO     Thermo Fisher Scientific Inc
# 47       NMS   ISRG         Intuitive Surgical, Inc.
# 50       NMS   INTU                      Intuit Inc.
# 51       NYQ     GS  Goldman Sachs Group, Inc. (The)
# 56       NMS   BKNG  Booking Holdings Inc. Common St
# 59       NYQ    BLK                  BlackRock, Inc.
# 103      NMS   EQIX                    Equinix, Inc.
# 116      NMS   KLAC                  KLA Corporation
# 119      NYQ     PH      Parker-Hannifin Corporation
# 128      NMS   REGN  Regeneron Pharmaceuticals, Inc.
# ...

# %%
df[df['Marketcap'] >= 2365033807872]
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 2      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 3      NMS   AMZN       Amazon.com, Inc.       Amazon.com, Inc.
#
#               Sector                   Industry  Currentprice      Marketcap  \
# 0         Technology       Consumer Electronics        254.49  3846819807232
# 1         Technology             Semiconductors        134.70  3298803056640
# 2         Technology  Software - Infrastructure        436.60  3246068596736
# 3  Consumer Cyclical            Internet Retail        224.92  2365033807872
#
#          Ebitda  Revenuegrowth         City State        Country  \
# 0  1.346610e+11          0.061    Cupertino    CA  United States
# 1  6.118400e+10          1.224  Santa Clara    CA  United States
# ...

# %%
df['Currentprice'].hist()
# Out:
# <Axes: >

# %%
df['Industry'].value_counts()

# %%
df['Industry'].value_counts(normalize=True)
# Out:
# Industry
# Utilities - Regulated Electric        0.045817
# Specialty Industrial Machinery        0.031873
# Software - Application                0.029880
# Software - Infrastructure             0.027888
# Semiconductors                        0.027888
#                                         ...
# Gold                                  0.001992
# Grocery Stores                        0.001992
# Rental & Leasing Services             0.001992
# Copper                                0.001992
# Furnishings, Fixtures & Appliances    0.001992
# Name: proportion, Length: 114, dtype: float64
